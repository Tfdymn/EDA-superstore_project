# %% [markdown]
# ## Exploratory Data Analysis of Superstore
#
# In this section, we will explore the dataset and understand:
# - The number of rows and columns
# - Missing values
# - Data types
# - Basic statistics
# - Visualization of Data
# - Comparison of data

# %% [markdown]
# First, we will import some necessary Libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading and saving the dataset

# %%
plt.style.use('Solarize_Light2')

# %%
df = pd.read_csv("../data/Sample - Superstore.csv", encoding="latin1")

# %% [markdown]
# ### Reading Data

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %% [markdown]
# This gives us info about the data like:
# - Dataset has 9994 rows and 21 columns
# - Data type of every element of the column

# %% [markdown]
# ### Cleaning Data
# **Checking null values and duplicates**

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# This tells us that there is no null value in this dataset

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# This tells us that there is no duplicated value overall

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# <Now we will set Row ID as index to get make the dataset looks more organized

# %%
df = df.set_index('Row ID')
df.tail()
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 9990    CA-2014-110422  1/21/2014  1/23/2014    Second Class    TB-21400
# 9991    CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9992    CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9993    CA-2017-121258  2/26/2017   3/3/2017  Standard Class    DB-13060
# 9994    CA-2017-119914   5/4/2017   5/9/2017    Second Class    CC-12220
#
#            Customer Name   Segment        Country         City       State  \
# Row ID
# 9990    Tom Boeckenhauer  Consumer  United States        Miami     Florida
# 9991         Dave Brooks  Consumer  United States   Costa Mesa  California
# 9992         Dave Brooks  Consumer  United States   Costa Mesa  California
# 9993         Dave Brooks  Consumer  United States   Costa Mesa  California
# 9994        Chris Cortes  Consumer  United States  Westminster  California
#
# ...

# %% [markdown]
# <Now we will check the dtype of Order date and Ship date

# %%
df[['Order Date', 'Ship Date']].dtypes
# Out:
# Order Date    str
# Ship Date     str
# dtype: object

# %% [markdown]
# There datatype is string so we will convert it into Datetime

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df[['Order Date', 'Ship Date']].dtypes
# Out:
# Order Date    datetime64[us]
# Ship Date     datetime64[us]
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 1 to 9994
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   str
#  1   Order Date     9994 non-null   datetime64[us]
#  2   Ship Date      9994 non-null   datetime64[us]
#  3   Ship Mode      9994 non-null   str
#  4   Customer ID    9994 non-null   str
#  5   Customer Name  9994 non-null   str
#  6   Segment        9994 non-null   str
#  7   Country        9994 non-null   str
#  8   City           9994 non-null   str
#  9   State          9994 non-null   str
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   str
#  12  Product ID     9994 non-null   str
#  13  Category       9994 non-null   str
#  14  Sub-Category   9994 non-null   str
#  15  Product Name   9994 non-null   str
#  16  Sales          9994 non-null   float64
#  17  Quantity       9994 non-null   int64
# ...

# %% [markdown]
# **The dataset has no missing values or duplicate rows, and the date columns have been converted to datetime.**

# %%
df.sample()
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 4757    CA-2017-169817 2017-09-21 2017-09-25  Standard Class    EB-13870
#
#        Customer Name   Segment        Country          City         State  \
# Row ID
# 4757     Emily Burns  Consumer  United States  Philadelphia  Pennsylvania
#
#         Postal Code Region       Product ID         Category Sub-Category  \
# Row ID
# 4757          19143   East  OFF-BI-10004141  Office Supplies      Binders
#
#                                    Product Name  Sales  Quantity  Discount  \
# Row ID
# 4757    Insertable Tab Indexes For Data Binders  1.908         2       0.7
#
#         Profit
# Row ID
# 4757   -1.5264

# %% [markdown]
# ### Analyzing and Visualizing Data
# **Let's check the total days taken to ship the order and add the Data in the Dataset**

# %%
df['Shipping period'] = df['Ship Date'] - df['Order Date']
df.sample()
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 7948    CA-2014-131009 2014-03-01 2014-03-05  Standard Class    SC-20380
#
#            Customer Name   Segment        Country     City  State  ...  \
# Row ID                                                             ...
# 7948    Shahid Collister  Consumer  United States  El Paso  Texas  ...
#
#          Region       Product ID         Category Sub-Category  \
# Row ID
# 7948    Central  OFF-FA-10004395  Office Supplies    Fasteners
#
#                                    Product Name  Sales  Quantity  Discount  \
# Row ID
# 7948    Plymouth Boxed Rubber Bands by Plymouth  18.84         5       0.2
#
#         Profit  Shipping period
# Row ID
# 7948   -3.5325           4 days
#
# [1 rows x 21 columns]

# %% [markdown]
# <Now let's check maximum days it took to ship any Order>

# %%
df['Shipping period'].sort_values(ascending= False)
# Out:
# Row ID
# 3298   7 days
# 4131   7 days
# 4133   7 days
# 7743   7 days
# 7739   7 days
#         ...
# 4304   0 days
# 988    0 days
# 9587   0 days
# 5601   0 days
# 5126   0 days
# Name: Shipping period, Length: 9994, dtype: timedelta64[us]

# %%
sns.countplot(x= df['Shipping period'].sort_values(ascending= False), color= 'orange')
# Out:
# <Axes: xlabel='Shipping period', ylabel='count'>

# %% [markdown]
# So the maximum days it took to ship any order is 7 days.
#
# Most of the orders took 4 days to be shipped.

# %%
df['Country'].unique()
# Out:
# <StringArray>
# ['United States']
# Length: 1, dtype: str

# %%
df['Year'] = df['Order Date'].dt.year
df
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 3       CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4       US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...                ...        ...        ...             ...         ...
# 9990    CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9991    CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992    CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993    CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9994    CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#            Customer Name    Segment        Country             City  \
# Row ID
# ...

# %%
print(df['State'].nunique())
df['City'].nunique()
# Out:
# 49
# 531

# %% [markdown]
# **This tells us that Orders were delievered to 49 state and 531 different cities of Unites States.**

# %%
df['Ship Mode'].unique()
# Out:
# <StringArray>
# ['Second Class', 'Standard Class', 'First Class', 'Same Day']
# Length: 4, dtype: str

# %% [markdown]
# There are 4 classes in total:
# - Standard Class
# - Second Class
# - First Class
# - Same Day

# %%
df.groupby('Ship Mode')['Quantity'].sum()
# Out:
# Ship Mode
# First Class        5693
# Same Day           1960
# Second Class       7423
# Standard Class    22797
# Name: Quantity, dtype: int64

# %% [markdown]
# This shows the total number of Quantity by different Classes

# %%
df['Segment'].unique()
# Out:
# <StringArray>
# ['Consumer', 'Corporate', 'Home Office']
# Length: 3, dtype: str

# %% [markdown]
# There are 3 Segments:
# - Consumer
# - Corporate
# - Home Office

# %% [markdown]
# Total Number of Quantity from these segments:

# %%
df.groupby('Segment')['Quantity'].sum()
# Out:
# Segment
# Consumer       19521
# Corporate      11608
# Home Office     6744
# Name: Quantity, dtype: int64

# %%
segment_profit = df.groupby('Segment')['Profit'].sum()
segment_profit
# Out:
# Segment
# Consumer       134119.2092
# Corporate       91979.1340
# Home Office     60298.6785
# Name: Profit, dtype: float64

# %%
sns.barplot(x= segment_profit.index ,y= segment_profit.values)
# Out:
# <Axes: xlabel='Segment'>

# %% [markdown]
# **The graph shows the total profit the store earned from these segmemts**

# %%
df.groupby('Region')['Quantity'].sum()
# Out:
# Region
# Central     8780
# East       10618
# South       6209
# West       12266
# Name: Quantity, dtype: int64

# %% [markdown]
# The above data says the total Quantities from all 4 regions.
#
# Most Quantity are coming from **West region** which are **3203** and Least Quantity are coming from **South region** which are **1620**

# %%
regional_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending= False)
regional_sales
# Out:
# Region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: Sales, dtype: float64

# %% [markdown]
# **Most total sales** are also coming from **West** region but **least total sales** are coming from **South**

# %%
sns.barplot(x= df['Region'], y= df['Sales'],hue= df['Category'], estimator= 'sum')
# Out:
# <Axes: xlabel='Region', ylabel='Sales'>

# %% [markdown]
# **This graph tells us about total sales of various regions divided category.**
#
# - In South, Technology has more total sales.
# - In west, Both Furniture and Technology has more sales.
# - In CentraL, again Technology has more sales.
# - In East, Technology has more total sales here too.

# %%
df.groupby('Region')['Profit'].sum().sort_values(ascending= False)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %% [markdown]
# **Most profit** are also coming from **West** region but **Least Profit** is coming from **Central** region.

# %%
sns.barplot(x= df['Region'], y= df['Profit'],hue= df['Category'], estimator= 'sum')
# Out:
# <Axes: xlabel='Region', ylabel='Profit'>

# %% [markdown]
# **This is the graph of total profit from different region divided by Category.**
# - In central region, Total profit of furniture is negative which means they are having loss in furniture in   central region. Further investigation needed and Total profit is high from Technology.
# - West region is getting high total profit from Office supplies.
# - East region is getting high total profit from Technology.
# - South region is getting high total profit from both Office Supplies and Technology.

# %%
df['Category'].unique()
# Out:
# <StringArray>
# ['Furniture', 'Office Supplies', 'Technology']
# Length: 3, dtype: str

# %% [markdown]
# All the orders from this superstore are from 3 Categories:
# - Furniture
# - Office Supplies
# - Technology

# %%
df.groupby('Category')['Quantity'].sum()
# Out:
# Category
# Furniture           8028
# Office Supplies    22906
# Technology          6939
# Name: Quantity, dtype: int64

# %% [markdown]
# **Office Supplies** has the **highest** total quantity sold among the three categories, while **Technology** has the lowest.

# %% [markdown]
# Total Orders related to various sub Categories are:

# %%
avg_category_profit = df.groupby('Category')['Profit'].mean().sort_values(ascending=False)
avg_category_profit
# Out:
# Category
# Technology         78.752002
# Office Supplies    20.327050
# Furniture           8.699327
# Name: Profit, dtype: float64

# %% [markdown]
# **Most Average profit** is coming from **Technology** Category and **least average profit** is coming from **Furniture**

# %%
sns.barplot(x= avg_category_profit.index, y= avg_category_profit.values,color= "yellow")
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# **This graph shows the average profit categorized by Category.**

# %%
df.groupby('Sub-Category')['Quantity'].sum().sort_values(ascending= False)
# Out:
# Sub-Category
# Binders        5974
# Paper          5178
# Furnishings    3563
# Phones         3289
# Storage        3158
# Art            3000
# Accessories    2976
# Chairs         2356
# Appliances     1729
# Labels         1400
# Tables         1241
# Fasteners       914
# Envelopes       906
# Bookcases       868
# Supplies        647
# Machines        440
# Copiers         234
# Name: Quantity, dtype: int64

# %% [markdown]
# This gives a very important piece of information and that is **Binders** have the **highest** total quantity sold, while **Copiers** have the **lowest**.

# %% [markdown]
# Finding loss from various sub-category:

# %%
subcategorical_value = df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending= False)
subcategorical_value
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
sns.barplot(x = subcategorical_value.values, y= subcategorical_value.index)
# Out:
# <Axes: ylabel='Sub-Category'>

# %% [markdown]
# **Tables** have the **lowest total profit**, while **Copiers** have the **highest total profit** among the sub-categories.
#
# Tables have the highest total loss among the sub-categories. This needs further investigation to understand the reason behind the loss.

# %%
df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending= False)
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %% [markdown]
# Most profit is gained by copiers but **most sales** are from **Phones**

# %%
df.sort_values(by= 'Sales',ascending= False)[['Order ID','Sales','Profit','Category']].head(5)
# Out:
#               Order ID      Sales     Profit    Category
# Row ID
# 2698    CA-2014-145317  22638.480 -1811.0784  Technology
# 6827    CA-2016-118689  17499.950  8399.9760  Technology
# 8154    CA-2017-140151  13999.960  6719.9808  Technology
# 2624    CA-2017-127180  11199.968  3919.9888  Technology
# 4191    CA-2017-166709  10499.970  5039.9856  Technology

# %% [markdown]
# This data is about the highest sales.
#
# Order ID  **CA-2014-145317** has highest sales but negative profit.
#
# All the **top sales** are from **Technology**.

# %%
df['Quantity'].nlargest()
# Out:
# Row ID
# 114     14
# 140     14
# 576     14
# 661     14
# 1046    14
# Name: Quantity, dtype: int64

# %%
df[['Region', 'Shipping period']].sort_values(by= 'Shipping period',ascending= False)
# Out:
#          Region Shipping period
# Row ID
# 3298       West          7 days
# 4131    Central          7 days
# 4133      South          7 days
# 7743       West          7 days
# 7739       East          7 days
# ...         ...             ...
# 4304    Central          0 days
# 988     Central          0 days
# 9587       West          0 days
# 5601       East          0 days
# 5126       East          0 days
#
# [9994 rows x 2 columns]

# %%
df['Year'].unique()
# Out:
# array([2016, 2015, 2014, 2017], dtype=int32)

# %%
sns.barplot(x= 'Year', y = 'Profit', estimator= 'sum', hue= 'Category', data= df.sort_values(by= "Year"))
plt.title("Year-wise profit")
# Out:
# Text(0.5, 1.0, 'Year-wise profit')

# %% [markdown]
# This graph shows the **year wise** **Total Profit** from different **Category**.
#
# **In 2014**, **Office suplies** provided **most profit** but after that it has been **technology** providing more profit.
#
# Profit from furniture has been always less.
#
# Overall, total profit shows an increasing trend over the years.

# %%
sns.scatterplot(x= 'Profit', y= 'Discount', data= df)
# Out:
# <Axes: xlabel='Profit', ylabel='Discount'>

# %% [markdown]
# This graph shows the relationship between discount and profit. We can see that higher discounts are often associated with lower profit.

# %%
sns.histplot(x= 'Sales', data= df, bins= 100,kde= True )
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.boxplot(x= 'Sales',data= df)
# Out:
# <Axes: xlabel='Sales'>

# %% [markdown]
# The boxplot shows several high-value observations in Sales, but because Sales has a strongly right-skewed distribution, the boxplot does not give much additional information beyond the histogram.

# %%
sns.boxplot(x = df['Profit'])
# Out:
# <Axes: xlabel='Profit'>

# %% [markdown]
# Same for profit , we can't get any useful information from boxplot

# %%
df['Discount'].corr(df['Profit'])
# Out:
# np.float64(-0.2194874563717678)

# %% [markdown]
# Discount and Profit have a weak negative correlation. Higher discounts tend to be associated with lower profit.

# %%
df['Sales'].corr(df['Profit'])
# Out:
# np.float64(0.47906434973770606)

# %% [markdown]
# Sales and Profit have a moderate positive correlation. Higher sales tend to be associated with higher profit.

# %%
df['Quantity'].corr(df['Profit'])
# Out:
# np.float64(0.06625318912428485)

# %% [markdown]
# Quantity and Profit have a very weak positive correlation. This means there is almost no linear relationship between them.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ***CONCLUSION***

# %% [markdown]
# - This Dataset has 9994 rows and 21 columns.
# - Datatypes: Float, Int, Str
#
# - Order to Ship period took at most 7 days.
# - Consumer has the highest total profit among the three segments.
#
# - West region orders maximum number of quantities and South region least.
# - Most Sales are also tends to associate with west region while least total Sales with South.
# - Most Profit are coming from West region while least profit from Central.
#
# - In Central region, Superstore seems to be having loss from furniture.
# - West region is getting high total profit from Office supplies.
# - East region is getting high total profit from Technology.
# - South region is getting high total Profit from both Office supplies and Technology.
#
# - Some sub-categories, including Bookcases and Tables, have negative total profit and need further investigation.
#
# - All the top Sales are from Technology.
# - Profit from furnitures has been always less.
#
# - Overall, total profit shows an increasing trend over the years.
#
# - Higher discounts are often associated with lower profit.
